# %% [markdown]
# <a href="https://colab.research.google.com/github/Saharuth/MachineLearning/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
print(f'pandas version: {pd.__version__}')
print(f'numpy version: {np.__version__}')
print(f'seaborn version: {sns.__version__}')

# %%
df = pd.read_csv('https://github.com/Saharuth/MachineLearning/raw/main/database_csv/heart_rate_report.csv')
print(df.head())
# Out:
#                         datetime                              thing_id  value
# 0  2023-08-15 17:09:11.986 +0700  888f934e-95a2-4973-91be-a81040d1001e   55.0
# 1  2023-08-15 17:22:16.243 +0700  888f934e-95a2-4973-91be-a81040d1001e   63.0
# 2  2023-08-15 17:26:08.401 +0700  888f934e-95a2-4973-91be-a81040d1001e   66.0
# 3  2023-08-15 17:29:34.227 +0700  888f934e-95a2-4973-91be-a81040d1001e   55.0
# 4  2023-08-15 17:33:47.364 +0700  888f934e-95a2-4973-91be-a81040d1001e   61.0

# %%
df2 = df[df['thing_id'] == '888f934e-95a2-4973-91be-a81040d1001e']
# df2['ts'] = df2.datetime.values.astype(np.int64)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 242 entries, 0 to 5997
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  242 non-null    object
#  1   thing_id  242 non-null    object
#  2   value     242 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 7.6+ KB

# %%
df2['datetime'] = pd.to_datetime(df2['datetime'])
df2['timestamp'] = (df2['datetime'].astype(int))
df2.sort_values('timestamp')
df2.reset_index(inplace = True)
df2['index'] = df2.index
print(df2.head())
print(df2.info())
# Out:
#    level_0                         datetime  \
# 0        0 2023-08-15 17:09:11.986000+07:00
# 1        1 2023-08-15 17:22:16.243000+07:00
# 2        2 2023-08-15 17:26:08.401000+07:00
# 3        3 2023-08-15 17:29:34.227000+07:00
# 4        4 2023-08-15 17:33:47.364000+07:00
#
#                                thing_id  value            timestamp  index
# 0  888f934e-95a2-4973-91be-a81040d1001e   55.0  1692094151986000000      0
# 1  888f934e-95a2-4973-91be-a81040d1001e   63.0  1692094936243000000      1
# 2  888f934e-95a2-4973-91be-a81040d1001e   66.0  1692095168401000000      2
# 3  888f934e-95a2-4973-91be-a81040d1001e   55.0  1692095374227000000      3
# 4  888f934e-95a2-4973-91be-a81040d1001e   61.0  1692095627364000000      4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level_0    242 non-null    int64
# ...

# %%
sns.lmplot(x='index', y='value', data=df2, ci=None)
